# %% [markdown]
# <a href="https://colab.research.google.com/github/sciencelee/mod4-xray-pneumonia-ML/blob/main/mod4_xray_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='green'>Introduction</font>

# %% [markdown]
# In this project we will create a Machine Learning model to classify chest x-ray images as positive or negative for pneumonia.
#
# Pneumonia is an oft misdiagnosed illness.  It's symptoms mimics: upper respiratory infections, influenza, cold, pleurisy, sinus infection, and seasonal viruses.  Pneumonia is a potentially life threatening condition with a mortality rate of 3.3%, and much higher when missed on the first visit. A hospital xray costs only $44 in the US health system.
#
# Pneumonia is also overly diagnosed when other underlying causes exist.  It leads to over prescribing of antibiotics, increased mortality, exposure to malpractice, and missing serious diseases such as: lung cancer, TB, pulmonary and cardiac disorders.
#
# Proper identification of a simple chest xray could help mitigate.
#
# The purpose of this project is to create a proof of concept model for helping identify pneumonia in pediatric patients.

# %% [markdown]
# # <font color='green'>Non-Technical Presentation</font>
#
#
# https://docs.google.com/presentation/d/1SdlY32Ac2sYzPgI47XhXPA95o7LxSLlrMaHC1BYpf8Q/edit?usp=sharing

# %% [markdown]
# #<font></font>
# A working web app of this project can be found at https://xray-pred.herokuapp.com/.
#
# A client can submit medical images to the site and receive a prediction (Normal/Pneumonia).
#
# The github repo for this webapp project https://github.com/sciencelee/flask-xray2

# %% [markdown]
# # <font color='green'>Dataset</font>
# The full dataset used in this project can be found [here](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) at kaggle.com.
#
# The kaggle dataset is taken adapted from the [original images](https://data.mendeley.com/datasets/rscbjbr9sj/3) at Mendeley Data.
#
# The labeled dataset contains 1583 normal chest xray images, and 4274 with pneumonia. The original images are greater than 1200x1200 pixels grayscale.

# %% [markdown]
# # <font color='green'>Initialization</font>

# %% [markdown]
# ##Google Drive
# This project is written in Google Colab.  The image folders are stored in These blocks mount the users google drive.  The chest xrays are stored in the path location of the drive.
#
# The structure of the xray images within the google folder is as shown. If you would like to recreate the project, all normal labeled images go in the "NORMAL ALL" folder, and all pneumonia labeled go in the 'PNEUMONIA ALL' folder.  This notebook will randomly place the desired `train test val` ratios of randomized images into the correct folders for reading into the datasets used in our model.
#
# ```
# chest_xray
#   └───NORMAL_ALL (contains all normal imgs)
#   └───PNEUMONIA_ALL (contains all pneumonia imgs)
#   └───train
#   │   └───NORMAL
#   │   └───PNEUMONIA
#   └───test
#   │   └───NORMAL
#   │   └───PNEUMONIA
#   └───val
#       └───NORMAL
#       └───PNEUMONIA
# ```
#
# The code below connects this ipynb to Google Drive.  To give access to your drive, you will need to give authorization.

# %%
# to get local files from the repo, run next line
# this will not get dataset
#!git clone https://github.com/sciencelee/mod4-xray-pneumonia-ML


# Owner of repo will add share permissions for folder chest_xray.  This will also provide dataset
# After shared, new user can mount drive with following code without modifications
from google.colab import drive # import drive from google colab

drive.mount('/content/drive') # we mount the google drive at /content/drive
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Imports
# Import all of the necessary libraries for this project

# %%
import datetime
import os
import time
import shutil
import datetime
from random import shuffle, seed


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

from PIL import Image
import scipy
from scipy import ndimage
from sklearn.metrics import accuracy_score, confusion_matrix
from keras import models, layers, optimizers
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing import image
from keras.models import load_model
from keras.utils import plot_model
from keras.layers import SpatialDropout2D


# %matplotlib inline

np.random.seed(123)

# %% [markdown]
# Store the paths to the working directory in Google Drive.

# %%
path = '/content/drive/MyDrive/chest_xray'
all_normal_folder = path + '/NORMAL_ALL/'
all_pneumonia_folder = path + '/PNEUMONIA_ALL/'

test_folder = path + '/test/'
train_folder = path + '/train/'
val_folder = path + '/val/'

# %% [markdown]
# # <font color='green'>Building Our Dataset</font>
# This section selects the dataset from existing files, and sorts the images into appropriate folders.
#
# Skip to the quick load section if you are not changing the dataset distribution.*italicized text*

# %% [markdown]
# ## Building our Train, Test, and Validation Datasets
# We will make lists of all of the image names for NORMAL and PNEUMONIA chest xrays.  Then we can divy up the images into individual folders for later use.
#
# I will also use this opportunity to randomize the images, and select the size of the dataset to use.  I will start with a small sets prior to building the final model.

# %% [markdown]
# We have two folders.  One for normal images, and one for pnemonia xray images.  In order to determine redistribute the images in a way different than original set on kaggle, we make a list of all the normal images, and all the pneumonia images and we shuffled each.
#
# This will give us a randomized list of all images that we can chop up into smaller datasets as need.

# %%
# Time: 1min

def shuffle_folder(folder_path, image_type):
  '''
  Returns a shuffled list of filenames from a folder.
            Parameters:
                    folder_path (string): path of the folder to with files I want
                    image_type (string): What types of files (normal or pneumonia)
            Returns:
                    filenames (list): shuffled list of all filenames in folder
  '''  
  filenames = [file for file in os.listdir(folder_path)]
  shuffle(filenames)
  print('There are {} {} xray images.'.format(len(filenames), image_type))
  return filenames



# Make a list of all normal images
normal_imgs = shuffle_folder(all_normal_folder, 'normal')

# Make a list of all pneumonia images
pneumonia_imgs = shuffle_folder(all_pneumonia_folder, 'pneumonia')
# Out:
# There are 1583 normal xray images.
# There are 4274 pneumonia xray images.

# %% [markdown]
# ## Split up our data into train, test, and val sets
# In the list train_test_val, we set up the distribution/percent desired for each dataset.  Values are entered as floats.  If I use [0.75, 0.25, 0.25] for this, we would images would be divided into 75% train, 25% test, and 25% val.
#
# We take our previously shuffled list of filenames, and make each into three smaller lists to divy them up.
#
# We also choose the size of our dataset (float from 0 to 1) to represent the percentage of images we want to use.  We want to reduce the size for testing.

# %%
# https://docs.python.org/3/library/shutil.html#shutil

# set distribution of datasets
train_test_val = [0.8, 0.1, 0.1] # must add to 1.0, these are the distributions

# What percentage of the dataset are we using
size_dataset = 1 # what percentage of dataset are we using? (0 to 1)

# NORMAL data indices
# indices for train, test, val
n_images_norm = int(round(len(normal_imgs) * size_dataset))

print(
'''
Percent of images used: {:.0%}. (lower this to speed up model iterations)
Train//Test//Val Split: {:.0%}, {:.0%}, {:.0%}
'''.format(size_dataset, train_test_val[0], train_test_val[1], train_test_val[2]))

# get the correct indices to chop up my NORMAL images from a shuffled list
norm_train_index = int(round(n_images_norm * train_test_val[0]))
norm_test_index = int(norm_train_index + round(n_images_norm * train_test_val[1]))
norm_val_index = min(norm_test_index + int(round(n_images_norm * train_test_val[2])), n_images_norm-1)

print('NORMAL xrays\nTotal images: {}\nIndices: {}, {}, {}'.format(n_images_norm, norm_train_index, norm_test_index, norm_val_index)) 

# PNEUMONIA data indices
# indices for train, test, val
n_images_pneu = int(round(len(pneumonia_imgs) * size_dataset))

# get the correct indices to chop up my PNEUMONIA images from a shuffled list
pneu_train_index = int(round(n_images_pneu * train_test_val[0]))
pneu_test_index = int(pneu_train_index + round(n_images_pneu * train_test_val[1]))
pneu_val_index = min(pneu_test_index + int(round(n_images_pneu * train_test_val[2])), n_images_pneu-1)


print('\nPNEUMONIA xrays\nTotal images: {}\nIndices: {}, {}, {}'.format(n_images_pneu, pneu_train_index, pneu_test_index, pneu_val_index))
# Out:
# Percent of images used: 100%. (lower this to speed up model iterations)
# Train//Test//Val Split: 80%, 10%, 10%
#
# NORMAL xrays
# Total images: 1583
# Indices: 1266, 1424, 1582
#
# PNEUMONIA xrays
# Total images: 4274
# Indices: 3419, 3846, 4273

# %% [markdown]
# Now that we have all of the names of images in a list, and we have the indices for the split, we will copy image files into the appropriate folders so we can use 'flow_from_directory' method in ImageDataGenerator.
#
# This may take a while.  This is definitely not something I would try on a larger dataset, but it works for this size and gives us some flexibility in training the model.

# %%
# ONLY RUN THIS CELL IF YOU WANT TO RECREATE THE DATASET. (1hr)
# ⏰ ⏰ ⏰ ⏰ ⏰ ⏰


answer = input("Are you sure you want to continue?")  


# if time, make function with code below.
if answer.upper() in ['Y', 'YES']:

  # empty all of the folders first
  shutil.rmtree(test_folder, ignore_errors=True)
  shutil.rmtree(train_folder, ignore_errors=True)
  shutil.rmtree(val_folder, ignore_errors=True)

  os.mkdir(test_folder)
  os.mkdir(test_folder + 'NORMAL')
  os.mkdir(test_folder + 'PNEUMONIA')
  os.mkdir(train_folder)
  os.mkdir(train_folder + 'NORMAL')
  os.mkdir(train_folder + 'PNEUMONIA')
  os.mkdir(val_folder)
  os.mkdir(val_folder + 'NORMAL')
  os.mkdir(val_folder + 'PNEUMONIA')

  # fill them back up with selected images

  # NORMAL images first
  for image in normal_imgs[:norm_train_index]:
    shutil.copyfile(all_normal_folder + image, train_folder + 'NORMAL/' + image)
  else:
    print(train_folder + 'NORMAL', 'complete')

  for image in normal_imgs[norm_train_index:norm_test_index]:
    shutil.copyfile(all_normal_folder + image, test_folder + 'NORMAL/' + image)
  else:
    print(test_folder + 'NORMAL', 'complete')

  for image in normal_imgs[norm_test_index:norm_val_index]:
    shutil.copyfile(all_normal_folder + image, val_folder + 'NORMAL/' + image)
  else:
    print(val_folder + 'NORMAL', 'complete')

  # PNEUMONIA images
  for image in pneumonia_imgs[:pneu_train_index]:
    shutil.copyfile(all_pneumonia_folder + image, train_folder + 'PNEUMONIA/' + image)
  else:
    print(train_folder + 'PNEUMONIA', 'complete')

  for image in pneumonia_imgs[pneu_train_index:pneu_test_index]:
    shutil.copyfile(all_pneumonia_folder + image, test_folder + 'PNEUMONIA/' + image)
  else:
    print(test_folder + 'PNEUMONIA', 'complete')

  for image in pneumonia_imgs[pneu_test_index:pneu_val_index]:
      shutil.copyfile(all_pneumonia_folder + image, val_folder + 'PNEUMONIA/' + image)
  else:
    print(val_folder + 'PNEUMONIA', 'complete')
# Out:
# Are you sure you want to continue?y
# /content/drive/MyDrive/chest_xray/train/NORMAL complete
# /content/drive/MyDrive/chest_xray/test/NORMAL complete
# /content/drive/MyDrive/chest_xray/val/NORMAL complete
# /content/drive/MyDrive/chest_xray/train/PNEUMONIA complete
# /content/drive/MyDrive/chest_xray/test/PNEUMONIA complete
# /content/drive/MyDrive/chest_xray/val/PNEUMONIA complete

# %% [markdown]
# ##Downsampling and generating datasets
# Now that we have our images separated into approrpriate folders, we will use ImageDataGenerator to pull them as a batch from the train, test, and val folders.
#
# In the process, we will downsample our images.  The typical unaltered image is about 1200x1200 (1.4 Megapixels).  We reduce them to 150x150 (22.5k pixels).  This is a loss of  98% of our original data, but will significantly speed up the training process.

# %%
# get all the data in the directory and downsample it
# you can also choose to just unpickle the image data
# ⏰  (30s)

print('TEST:')
n = len(os.listdir(test_folder + 'PNEUMONIA')) + len(os.listdir(test_folder + 'NORMAL'))
test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        test_folder, 
        target_size=(150, 150),
        batch_size=n
        ) 

print('\nVAL:')
n = len(os.listdir(val_folder + 'PNEUMONIA')) + len(os.listdir(val_folder + 'NORMAL'))
val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        val_folder, 
        target_size=(150, 150),
        batch_size=n
        )

print('\nTRAIN:')
n = len(os.listdir(train_folder + 'PNEUMONIA')) + len(os.listdir(train_folder + 'NORMAL'))
train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        train_folder, 
        target_size=(150, 150),
        batch_size=n
        )


 
# I ENDED ON A 80/10/10 ratio in the folders, but experiemented with 60/20/20 first.  
# Results were better with more training images
# Out:
# TEST:
# Found 585 images belonging to 2 classes.
#
# VAL:
# Found 585 images belonging to 2 classes.
#
# TRAIN:
# Found 4685 images belonging to 2 classes.

# %% [markdown]
# The following lines will generate my images and labels that I will use to create my models.  The generators will output labels (0 for normal, and 1 for pneumonia) for the labels.  The images are np matrices.

# %%
# create the data sets. 
# you can also choose to just unpickle with the block above
# ⏰ ⏰ ⏰ ⏰ ⏰ ⏰
answer = input("Are you sure you want to create new datasets?  (Expect 30 min wait): ")

if answer.lower() in ["y", 'yes']:
  # load them up anew
  test_images, test_labels = next(test_generator)
  print('Test')
  val_images, val_labels = next(val_generator)
  print('Val')
  train_images, train_labels = next(train_generator)
  print('Train')
# Out:
# Are you sure you want to create new datasets?  (Expect 30 min wait): n

# %%
# the last block took soooo long, i want to pickle it

import pickle

file_location = "/content/drive/MyDrive/chest_xray/big_image_sets.pkl"

data = [test_images, test_labels, val_images, val_labels, train_images, train_labels]
with open(file_location, "wb") as f:
    pickle.dump(data, f)

# To retrieve it later...
# with open(file_location, "rb") as f:
#      test_images, test_labels, val_images, val_labels, train_images, train_labels = pickle.load(f)

# %% [markdown]
# # <font color='green'>Quick Load</font>
# Run this instead of rebuilding the dataset
# Instead of rebuilding the entire dataset and loading images with the Project Setup above, use this section to simply load the already assembled and downsampled data.

# %%
# To load up the pickled image datasets, run this block
import pickle


my_file = "/content/drive/MyDrive/chest_xray/big_image_sets.pkl"
with open(my_file, "rb") as f:
     test_images, test_labels, val_images, val_labels, train_images, train_labels = pickle.load(f)

# %% [markdown]
# # <font color='green'>Our Images</font>

# %% [markdown]
# ## A survey of images
# First, we will just examine an image from the dataset to see investigate properties and color scales.  The images in the dataset are not uniform.
#
# The images have varying height, width, pixels, and contrast.  Some are more in portrait mode, and others in landscape.  Some show a significant amount of arms or skull.
#
# This are also a wide variety of ages of the patient, from infants to what seems like roughly adult bone structures.  The younger patients sometimes have awkward poses or are twisting in the picture.  Some patients are hooked up to EKG pads during the xray.  Most images have some writing on them to identify right side.

# %%
# Original image investigation
filename = all_normal_folder + os.listdir(all_normal_folder)[337] # change index to look at other images
sample_img = plt.imread(filename)

plt.figure(figsize=[16,8])
plt.subplot(121) 
plt.imshow(sample_img, cmap='gray')
plt.colorbar()
plt.title('Raw Chest X Ray Grayscale')

plt.subplot(122) 
plt.imshow(sample_img, cmap='Spectral_r')
plt.colorbar()
plt.title('Raw Chest X Ray Spectral')

print("{}x{} image. Single color channel.".format(sample_img.shape[0], sample_img.shape[1]))
print('Max pixel value: {}\nMin pixel value: {}'.format(sample_img.max(), sample_img.min()))
print('Mean value: {:.2f}\nStd Dev: {:.2f}'.format(sample_img.mean(), sample_img.std()))
# Out:
# 1496x1952 image. Single color channel.
# Max pixel value: 255
# Min pixel value: 0
# Mean value: 110.20
# Std Dev: 65.53

# %% [markdown]
# Now that we have downsampled the pics, we can take a look at our 150x150 pics.  Some of the images have odd aspect ratios, but the features are all still visible at this resolution.  We can also see the difference between pneumonia and normal images.
#
# Image 8 is bacterial pneumonia.
# Image 1 is viral pneumonia
# Image 2 is normal.
#
# When looking at these images, we can see that it is more difficult for the human eye to distinguish between normal and viral pneumonia images than between normal and bacterial pneumonia which have obvious hazy smudges on the image.

# %%
for i in range(8):
  plt.figure(figsize=(12,6))  # change the size of figure!
  plt.subplot(121)
  my_img = train_images[i]
  classification = 'Normal' if train_labels[i][1]==0 else 'Pneumonia'

  plt.imshow(my_img)
  plt.title('{}. {}'.format(i + 1, classification))
  label = "Mean: {:.2f}, SD: {:.2f} Label: {}".format(np.mean(my_img), np.std(my_img), classification)
  
  plt.subplot(122)
  sns.distplot(my_img,
              label=label,
              kde=False)
  plt.legend()
  plt.title('Pixel Intensity of X-ray Images')
  plt.xlabel('Pixel Intensity')
  plt.ylabel('Total Pixels')
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# DOWNSAMPLED PICS
plt.figure(figsize=(16,16))  # change the size of figure!

for i in range(16):
    img = train_images[i]
    image_label = 'NORMAL' if train_labels[i][1] == 0 else 'PNEUMONIA'

    plt.subplot(4, 4, i+1)
    plt.imshow(img)
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)
    plt.title(image_label)  # Plot title here!!!

plt.show()

# %% [markdown]
# I also notice that the pneumonia images are a lot brighter for the most part, so I decided to count up all of the black pixels to see if there was an obvious difference.  The normal images indeed have twice as many pure black pixels.
#
# Another, more important thing we observe is that there is a big weight imbalance between normal and pneumonial images.

# %%
# This block grabs some basic stats for all downsampled images

def print_stats(title, my_stats, pixels, n):
    print(title + " Pixel Intensity (n = {})".format(n))
    print('Mean:             {:.3f}'.format(my_stats[0]))
    print('Std:              {:.3f}'.format(my_stats[1]))
    print('Black (0) Pixels: {:.2f}%'.format(my_stats[2] / pixels * 100))
    print('White (1) Pixels: {:.2f}%'.format(my_stats[3] / pixels * 100))


def some_stats(images, labels):
  p_stats = [0, 0, 0, 0] # mean std black white
  n_stats = [0, 0, 0, 0]
  n_p = 0 # n pneu
  n_n = 0 # n normal
  pixels = len(images[0]) * len(images[0][0]) * 3 #3 channels

  for i in range(len(images)):
      my_img = images[i].flatten()
      if labels[i][1] == 1:
          n_p += 1
          p_stats[0] += my_img.mean()
          p_stats[1] += np.std(my_img)
          p_stats[2] += np.count_nonzero(my_img == 0)
          p_stats[3] += np.count_nonzero(my_img == 1)

      else:
          n_n += 1
          n_stats[0] += img.mean()
          n_stats[1] += img.std()
          n_stats[2] += np.count_nonzero(my_img == 0)
          n_stats[3] += np.count_nonzero(my_img == 1)

  else:
    n_stats = np.array(n_stats) / n_n
    p_stats = np.array(p_stats) / n_p
  
  weight_normal = n_n / (n_n + n_p)
  weight_pneumonia = 1 - weight_normal 
  print('Dataset Imbalance: {:.1f} Normal, {:.1f} Pneumonia'.format(weight_normal * 100, weight_pneumonia * 100))
  print()
  print_stats('Normal', n_stats, pixels, n_n)
  print()
  print_stats('Pneumonia', p_stats, pixels, n_p)

# function just prints out some stats of interest from downsampled data
some_stats(train_images, train_labels)
# Out:
# Dataset Imbalance: 27.0 Normal, 73.0 Pneumonia
#
# Normal Pixel Intensity (n = 1266)
# Mean:             0.491
# Std:              0.210
# Black (0) Pixels: 7.67%
# White (1) Pixels: 0.07%
#
# Pneumonia Pixel Intensity (n = 3419)
# Mean:             0.483
# Std:              0.217
# Black (0) Pixels: 3.82%
# White (1) Pixels: 0.04%

# %% [markdown]
# Our images are indeed 150x150.  We see that they have three channels RGB.  They are actually grayscale images, but all three channels are identical.  No need to change the image going in.

# %%
train_images[0].shape
# Out:
# (150, 150, 3)

# %% [markdown]
# Here are some basic stats on my downsampled images and labels.  We verify the shapes are as expected for all datasets.

# %%
# Explore your dataset again
m_train = train_images.shape[0]
num_px = train_images.shape[1]
m_test = test_images.shape[0]
m_val = val_images.shape[0]

print ("Number of training samples: " + str(m_train))
print ("Number of testing samples: " + str(m_test))
print ("Number of validation samples: " + str(m_val))
print ("train_images shape: " + str(train_images.shape))
print ("train_labels shape: " + str(train_labels.shape))
print ("test_images shape: " + str(test_images.shape))
print ("test_labels shape: " + str(test_labels.shape))
print ("val_images shape: " + str(val_images.shape))
print ("val_labels shape: " + str(val_labels.shape))
# Out:
# Number of training samples: 4685
# Number of testing samples: 585
# Number of validation samples: 585
# train_images shape: (4685, 150, 150, 3)
# train_labels shape: (4685, 2)
# test_images shape: (585, 150, 150, 3)
# test_labels shape: (585, 2)
# val_images shape: (585, 150, 150, 3)
# val_labels shape: (585, 2)

# %% [markdown]
# For the next cell, we just reshape our images so that they are a 'flat' 150x150x3 input so we can do a baseline model.
#
# We will retain the full images so we can later do a CNN which requires the shape to do 2Dconv layers.

# %%
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (4685, 67500)
# (585, 67500)
# (585, 67500)

# %% [markdown]
# rehape the labels which only need a single result (0 or 1). Currently, they have a column for pneumonia and one for normal which is unecessary.  We choose everything in the first column which is normal.

# %%
# use labels[: 1] so that we have pneumonia as 1 and normal as 0
train_y = np.reshape(train_labels[:,1], (train_img.shape[0],1))
test_y = np.reshape(test_labels[:,1], (test_img.shape[0],1))
val_y = np.reshape(val_labels[:,1], (val_img.shape[0],1))

# %%
print('Before:', train_labels[0])
print("After:", train_y[0])
# Out:
# Before: [0. 1.]
# After: [1.]

# %% [markdown]
# # <font color='green'>Model 1: Baseline Model</font>
# We will send in a flat "150 \* 150 \* 3 = 67500" matrix for our input, and do it as we would for any Neural Network using Dense layers.
#
# We chose to use an input layer, three hidden layers, and an output to a single

# %% [markdown]
# ##Build Model

# %%
# Build a baseline fully connected model
np.random.seed(123)
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(67500,))) # 2 hidden layers
model.add(layers.Dense(12, activation='relu'))
model.add(layers.Dense(6, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# ## Train Model
# Vanilla model.  We choose some basic numbers.  I did minimal tuning of this model since it is our baseline.  I adjusted the number of epochs down to 30.

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

hist = model.fit(train_img,
                    train_y,
                    epochs=30,
                    batch_size=20,
                    steps_per_epoch=100,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.5538 - accuracy: 0.7215 - val_loss: 0.4160 - val_accuracy: 0.7299
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5883 - accuracy: 0.7115 - val_loss: 0.6702 - val_accuracy: 0.7299
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6482 - accuracy: 0.7456 - val_loss: 0.6354 - val_accuracy: 0.7299
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6312 - accuracy: 0.7160 - val_loss: 0.6178 - val_accuracy: 0.7299
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6052 - accuracy: 0.7411 - val_loss: 0.6042 - val_accuracy: 0.7299
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6064 - accuracy: 0.7200 - val_loss: 0.5975 - val_accuracy: 0.7299
# Epoch 7/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5921 - accuracy: 0.7340 - val_loss: 0.5924 - val_accuracy: 0.7299
# Epoch 8/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5862 - accuracy: 0.7360 - val_loss: 0.5891 - val_accuracy: 0.7299
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5943 - accuracy: 0.7220 - val_loss: 0.5874 - val_accuracy: 0.7299
# Epoch 10/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5849 - accuracy: 0.7320 - val_loss: 0.5860 - val_accuracy: 0.7299
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5790 - accuracy: 0.7375 - val_loss: 0.5849 - val_accuracy: 0.7299
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5980 - accuracy: 0.7149 - val_loss: 0.5847 - val_accuracy: 0.7299
# Epoch 13/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5666 - accuracy: 0.7265 - val_loss: 0.5216 - val_accuracy: 0.7299
# Epoch 14/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4360 - accuracy: 0.7445 - val_loss: 0.4224 - val_accuracy: 0.7299
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4466 - accuracy: 0.7209 - val_loss: 0.5343 - val_accuracy: 0.7299
# Epoch 16/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4226 - accuracy: 0.7300 - val_loss: 0.4800 - val_accuracy: 0.7299
# Epoch 17/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3878 - accuracy: 0.7446 - val_loss: 0.3555 - val_accuracy: 0.7299
# Epoch 18/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4003 - accuracy: 0.7180 - val_loss: 0.3730 - val_accuracy: 0.7299
# Epoch 19/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3591 - accuracy: 0.7295 - val_loss: 0.3328 - val_accuracy: 0.7299
# Epoch 20/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3366 - accuracy: 0.7285 - val_loss: 0.3879 - val_accuracy: 0.7299
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3449 - accuracy: 0.7255 - val_loss: 0.3055 - val_accuracy: 0.7299
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3342 - accuracy: 0.7431 - val_loss: 0.2925 - val_accuracy: 0.9214
# Epoch 23/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3210 - accuracy: 0.8970 - val_loss: 0.2853 - val_accuracy: 0.9231
# Epoch 24/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2918 - accuracy: 0.9174 - val_loss: 0.3879 - val_accuracy: 0.8564
# Epoch 25/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3022 - accuracy: 0.9135 - val_loss: 0.2687 - val_accuracy: 0.9265
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2816 - accuracy: 0.9083 - val_loss: 0.3232 - val_accuracy: 0.8650
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2807 - accuracy: 0.9090 - val_loss: 0.2820 - val_accuracy: 0.9009
# Epoch 28/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2857 - accuracy: 0.9015 - val_loss: 0.2540 - val_accuracy: 0.9197
# Epoch 29/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2706 - accuracy: 0.9179 - val_loss: 0.2649 - val_accuracy: 0.9060
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2491 - accuracy: 0.9165 - val_loss: 0.2508 - val_accuracy: 0.9145

# %% [markdown]
# ##Evaluate Model
# We are evaluating model for test accuracy.  Difference between test and train, along with history, will help us quickly tune it to prevent over/under fit.

# %%
# The number of epochs was reduced to prevent overfit
print("Baseline Model Results")
results_train = model.evaluate(train_img, train_y)
results_test = model.evaluate(test_img, test_y)

print("Test Accuracy: {:.1f}%".format(results_test[1] * 100))
# Out:
# Baseline Model Results
# 147/147 [==============================] - 1s 6ms/step - loss: 0.2429 - accuracy: 0.9283
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2189 - accuracy: 0.9419
# Test Accuracy: 94.2%

# %% [markdown]
# That's a pretty good first result using 50% of dataset we achieved 90% on test set.
#
# With entire dataset, we achieved 95%.
#
# This model was set for speed and to determine a baseline.  We did very little tuning with the layers, but this seemed to be a reliable performance.
#
# We will now try to tune and use other methods to improve our result
#
# Before we go, we will also save our model in case we want to see it again.

# %% [markdown]
# ##Save Model

# %%
# save to google drive
model.save('/content/drive/MyDrive/chest_xray/chest_xray_baseline_100_801010.h5')

# %% [markdown]
# # <font color='green'>Model 2: CNN **Baseline**</font>
# Convolutional Neural Networks are good at image classification.  Instead of simply putting in a flat 67500 value input, we will use 2D convulution layers and max pooling layers to achieve feature recognition and hopefully improve our accuracy/precision.

# %% [markdown]
# ## Build Model

# %% [markdown]
# We will time our models, as these may take a while.  We will take advantage of GPU for these CNN tasks to speed things up considerably.  In my trials, it took less than half the time when operating on GPU.

# %%
original_start = datetime.datetime.now()
start = datetime.datetime.now() #We want to keep track of time.  This could take a while.

# %% [markdown]
# We will create ImageDataGenerators to automatically pull x and y data from the directory which is split into folders.  We reduce our image size to 150.  I tried larger, but there was a RAM limit for colab that prevented it.
#
# We chose batch size of 32 images, which will affect parameters we choose for model fit.
#
# Mode must be 'binary' since we are looking for straight one category classification.

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255) # this scaling should prevent errors of local maxima minima and get better results
test_datagen = ImageDataGenerator(rescale=1./255)


# we are going to do another generator for our data.  Not for our test though, we need that to be normal
train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_folder,
        # All images will be resized to 150x150, same as baseline
        target_size=(150, 150),
        batch_size=32,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(val_folder,
                                                        target_size=(150, 150),
                                                        batch_size=32,
                                                        class_mode='binary')
# Out:
# Found 4685 images belonging to 2 classes.
# Found 585 images belonging to 2 classes.

# %% [markdown]
# Create our CNN.  I originally tried 300x300 input, but ran out of RAM on colab.  Would need to go Colab Pro to do this.
#
# This model is three convolutional layers which expand in size/nodes.  The max pooling layers reduce the data size (half).
#
# Input is square (150^2) as best practice.  We are using 3x3 kernel.  Experimenting with 5x5 and 7x7 had worse results.

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150,150,3)))
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Conv2D(64, (3, 3), activation='relu')) # relu makes it speedy
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Conv2D(128, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Conv2D(128, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Flatten())
model2.add(layers.Dense(512, activation='relu')) # fully connected layer

model2.add(layers.Dense(1, activation='sigmoid')) # sigmoid to the output layer

# %%
model2.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %% [markdown]
# ##Train Model
#
# I have about 4000 images or so.
# One step takes a complete batch of images, i.e. if your batch_size is 32, you run out of data after 100+ steps (100 * 32 = 3200).
#
# Same concept with validation steps. I only have 500+ images, so my validation steps have to be (500 // 32 = 15)
#
# That will prevent the input ran out of data error I was getting.

# %%
# ⏰⏰⏰⏰⏰⏰⏰⏰⏰⏰⏰⏰⏰⏰
# After some tinkering, and monitoring the training history, I got the time down to 16s per epoch
# Thats about 15 minutes 

# This cell may take many many minutes to run depending on size of set and model
# best on a GPU, but beware, if you choose GPU at this point, you'll have to start over

history2 = model2.fit(train_generator, 
                              steps_per_epoch=125, 
                              epochs=20, 
                              validation_data=validation_generator, 
                              validation_steps=15)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 1368s 11s/step - loss: 0.4237 - acc: 0.8078 - val_loss: 0.2444 - val_acc: 0.9083
# Epoch 2/20
# 125/125 [==============================] - 232s 2s/step - loss: 0.2435 - acc: 0.9015 - val_loss: 0.2025 - val_acc: 0.9167
# Epoch 3/20
# 125/125 [==============================] - 75s 598ms/step - loss: 0.1879 - acc: 0.9272 - val_loss: 0.1672 - val_acc: 0.9333
# Epoch 4/20
# 125/125 [==============================] - 51s 408ms/step - loss: 0.1672 - acc: 0.9367 - val_loss: 0.1820 - val_acc: 0.9208
# Epoch 5/20
# 125/125 [==============================] - 48s 382ms/step - loss: 0.1541 - acc: 0.9420 - val_loss: 0.1533 - val_acc: 0.9479
# Epoch 6/20
# 125/125 [==============================] - 47s 378ms/step - loss: 0.1324 - acc: 0.9498 - val_loss: 0.2549 - val_acc: 0.9146
# Epoch 7/20
# 125/125 [==============================] - 48s 382ms/step - loss: 0.1283 - acc: 0.9518 - val_loss: 0.1210 - val_acc: 0.9458
# Epoch 8/20
# 125/125 [==============================] - 47s 377ms/step - loss: 0.1188 - acc: 0.9553 - val_loss: 0.1767 - val_acc: 0.9396
# Epoch 9/20
# 125/125 [==============================] - 48s 385ms/step - loss: 0.1181 - acc: 0.9568 - val_loss: 0.1105 - val_acc: 0.9521
# Epoch 10/20
# 125/125 [==============================] - 48s 384ms/step - loss: 0.1094 - acc: 0.9582 - val_loss: 0.1204 - val_acc: 0.9479
# Epoch 11/20
# 125/125 [==============================] - 48s 381ms/step - loss: 0.1009 - acc: 0.9660 - val_loss: 0.0975 - val_acc: 0.9521
# Epoch 12/20
# 125/125 [==============================] - 48s 386ms/step - loss: 0.0954 - acc: 0.9671 - val_loss: 0.0985 - val_acc: 0.9646
# Epoch 13/20
# 125/125 [==============================] - 48s 388ms/step - loss: 0.0905 - acc: 0.9696 - val_loss: 0.1242 - val_acc: 0.9521
# Epoch 14/20
# 125/125 [==============================] - 48s 383ms/step - loss: 0.0880 - acc: 0.9696 - val_loss: 0.1300 - val_acc: 0.9479
# Epoch 15/20
# 125/125 [==============================] - 48s 388ms/step - loss: 0.0797 - acc: 0.9709 - val_loss: 0.1011 - val_acc: 0.9625
# Epoch 16/20
# 125/125 [==============================] - 48s 383ms/step - loss: 0.0756 - acc: 0.9736 - val_loss: 0.1301 - val_acc: 0.9479
# Epoch 17/20
# 125/125 [==============================] - 48s 385ms/step - loss: 0.0724 - acc: 0.9745 - val_loss: 0.1117 - val_acc: 0.9625
# Epoch 18/20
# 125/125 [==============================] - 48s 384ms/step - loss: 0.0695 - acc: 0.9749 - val_loss: 0.1453 - val_acc: 0.9500
# Epoch 19/20
# 125/125 [==============================] - 48s 384ms/step - loss: 0.0622 - acc: 0.9802 - val_loss: 0.1057 - val_acc: 0.9604
# Epoch 20/20
# 125/125 [==============================] - 48s 383ms/step - loss: 0.0588 - acc: 0.9802 - val_loss: 0.1422 - val_acc: 0.9542

# %% [markdown]
# ##Evaluate Model

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               3211776
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.style.use('ggplot')
acc = history2.history['acc']
loss = history2.history['loss']
epochs = range(len(acc))
plt.figure(figsize=[12,4])
plt.plot(epochs, acc, 'b-', label='acc')
plt.title('Training accuracy')
plt.legend()
plt.figure(figsize=[12,4])
plt.plot(epochs, loss, 'b-', label='loss')
plt.title('Training loss')
plt.legend()
plt.show()

# %% [markdown]
# The accuracy with just 50% of the dataset is over 96% (training acc).  Let's see how it performs with new data.

# %%
end = datetime.datetime.now()
elapsed = end - start
print('Training took a total of {}'.format(elapsed))
# Out:
# Training took a total of 0:43:56.675783

# %%
test_generator = test_datagen.flow_from_directory(test_folder, 
                                                  target_size=(150, 150), 
                                                  batch_size=32, 
                                                  class_mode='binary')

test_loss, test_acc = model2.evaluate_generator(test_generator, steps=20)
print('test acc:', test_acc)

# %% [markdown]
# After reducing the number of epochs to 50 (from 100 and then 80) I retained 95.9% accuracy on the test set.  This is practically unchanged from the 100 epochs which had clear overfitting.  I altered the batch size and steps, and was able to get it up to about 97%

# %%
3# LETS GET SOME RESULTS
# my labels are backwards 0 instead of 1 for pneumonia
# fixed here, but should go back and repair earlier.  Also noted there.
# Basically, my model was trained backwards, but results are same.

results_train = model2.evaluate(train_images, train_y)
print(results_train)

test_y_inverse = np.array([1 if x==0 else 0 for x in test_y])
results_test = model2.evaluate(test_images, test_y)
print(results_test)
# Out:
# 147/147 [==============================] - 1s 10ms/step - loss: 0.0701 - acc: 0.9742
# [0.07006251811981201, 0.9741728901863098]
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0579 - acc: 0.9709
# [0.05794680863618851, 0.9709401726722717]

# %% [markdown]
# ##Save Model

# %%
model2.save('/content/drive/MyDrive/chest_xray/chest_xray_cnn_100_801010.h5')

f = open('/content/drive/MyDrive/chest_xray/history2.pkl', 'wb')
pickle.dump(history2.history, f)

# with open('content/drive/MyDrive/chest_xray/history2.pkl', 'rb') as f:
#     history3 = pickle.load(f)

# %% [markdown]
# # <font color='green'>Model 3: CNN with Dropout</font>
# I wanted to try an advanced strategy.  The options I considered, and may still attempt are:
# - dropout
# - cropping the images to focus on lungs
# - undersampling to fix weighting
# - oversampling the normal images
# - image augmentation with brightness/rotation etc.
#
# This is my first attempt.  I started with 0.5 dropout on all layers after maxpool.  I reduced to 0.2, and eventually dropped two of the dropouts until accuracy improved.

# %%
# I want to try a dropout strategy.  Not sure if it applies here

model3 = models.Sequential()

model3.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Conv2D(64, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))

model3.add(layers.Conv2D(128, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(SpatialDropout2D(0.2))

model3.add(layers.Conv2D(128, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(SpatialDropout2D(0.2))

model3.add(layers.Flatten())
model3.add(layers.Dense(512, activation='relu'))
model3.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# ##Training

# %% [markdown]
# Used the same setup as previous CNN model

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255) # this scaling should prevent errors of local maxima minima and get better results
test_datagen = ImageDataGenerator(rescale=1./255)


# we are going to do another generator for our data.  Not for our test though, we need that to be normal
train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_folder,
        # All images will be resized to 150x150, same as baseline
        target_size=(150, 150),
        batch_size=32,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(val_folder,
                                                        target_size=(150, 150),
                                                        batch_size=32,
                                                        class_mode='binary')
# Out:
# Found 4685 images belonging to 2 classes.
# Found 585 images belonging to 2 classes.

# %%
model3.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %% [markdown]
# Reduced the number of epochs and implemented dropout layers to hopefully prevent overfitting which appears to occur around 50 epochs in.

# %%
history3 = model3.fit(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=validation_generator, 
                              validation_steps=15)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 47s 379ms/step - loss: 0.5063 - acc: 0.7719 - val_loss: 0.3005 - val_acc: 0.9167
# Epoch 2/30
# 125/125 [==============================] - 46s 370ms/step - loss: 0.2851 - acc: 0.8839 - val_loss: 0.1945 - val_acc: 0.9208
# Epoch 3/30
# 125/125 [==============================] - 46s 366ms/step - loss: 0.2129 - acc: 0.9148 - val_loss: 0.2350 - val_acc: 0.9021
# Epoch 4/30
# 125/125 [==============================] - 46s 367ms/step - loss: 0.1811 - acc: 0.9304 - val_loss: 0.1575 - val_acc: 0.9333
# Epoch 5/30
# 125/125 [==============================] - 46s 365ms/step - loss: 0.1729 - acc: 0.9322 - val_loss: 0.1647 - val_acc: 0.9396
# Epoch 6/30
# 125/125 [==============================] - 46s 364ms/step - loss: 0.1539 - acc: 0.9440 - val_loss: 0.1270 - val_acc: 0.9417
# Epoch 7/30
# 125/125 [==============================] - 46s 366ms/step - loss: 0.1426 - acc: 0.9460 - val_loss: 0.1550 - val_acc: 0.9458
# Epoch 8/30
# 125/125 [==============================] - 46s 368ms/step - loss: 0.1390 - acc: 0.9495 - val_loss: 0.1543 - val_acc: 0.9417
# Epoch 9/30
# 125/125 [==============================] - 45s 360ms/step - loss: 0.1330 - acc: 0.9495 - val_loss: 0.1390 - val_acc: 0.9479
# Epoch 10/30
# 125/125 [==============================] - 45s 363ms/step - loss: 0.1224 - acc: 0.9545 - val_loss: 0.1682 - val_acc: 0.9292
# Epoch 11/30
# 125/125 [==============================] - 45s 363ms/step - loss: 0.1231 - acc: 0.9550 - val_loss: 0.2137 - val_acc: 0.9146
# Epoch 12/30
# 125/125 [==============================] - 45s 363ms/step - loss: 0.1136 - acc: 0.9608 - val_loss: 0.1245 - val_acc: 0.9438
# Epoch 13/30
# 125/125 [==============================] - 45s 362ms/step - loss: 0.1102 - acc: 0.9596 - val_loss: 0.1129 - val_acc: 0.9542
# Epoch 14/30
# 125/125 [==============================] - 45s 363ms/step - loss: 0.1050 - acc: 0.9618 - val_loss: 0.0940 - val_acc: 0.9604
# Epoch 15/30
# 125/125 [==============================] - 46s 364ms/step - loss: 0.1057 - acc: 0.9666 - val_loss: 0.1341 - val_acc: 0.9396
# Epoch 16/30
# 125/125 [==============================] - 45s 363ms/step - loss: 0.0983 - acc: 0.9658 - val_loss: 0.0939 - val_acc: 0.9583
# Epoch 17/30
# 125/125 [==============================] - 45s 362ms/step - loss: 0.1034 - acc: 0.9656 - val_loss: 0.1106 - val_acc: 0.9604
# Epoch 18/30
# 125/125 [==============================] - 45s 362ms/step - loss: 0.0934 - acc: 0.9666 - val_loss: 0.1170 - val_acc: 0.9583
# Epoch 19/30
# 125/125 [==============================] - 46s 366ms/step - loss: 0.0957 - acc: 0.9658 - val_loss: 0.0949 - val_acc: 0.9563
# Epoch 20/30
# 125/125 [==============================] - 45s 359ms/step - loss: 0.0882 - acc: 0.9694 - val_loss: 0.1084 - val_acc: 0.9604
# Epoch 21/30
# 125/125 [==============================] - 45s 361ms/step - loss: 0.0825 - acc: 0.9678 - val_loss: 0.1237 - val_acc: 0.9417
# Epoch 22/30
# 125/125 [==============================] - 46s 366ms/step - loss: 0.0865 - acc: 0.9691 - val_loss: 0.1171 - val_acc: 0.9563
# Epoch 23/30
# 125/125 [==============================] - 46s 365ms/step - loss: 0.0833 - acc: 0.9691 - val_loss: 0.1170 - val_acc: 0.9563
# Epoch 24/30
# 125/125 [==============================] - 46s 364ms/step - loss: 0.0711 - acc: 0.9749 - val_loss: 0.1047 - val_acc: 0.9563
# Epoch 25/30
# 125/125 [==============================] - 46s 367ms/step - loss: 0.0749 - acc: 0.9761 - val_loss: 0.1086 - val_acc: 0.9625
# Epoch 26/30
# 125/125 [==============================] - 45s 362ms/step - loss: 0.0701 - acc: 0.9754 - val_loss: 0.1147 - val_acc: 0.9479
# Epoch 27/30
# 125/125 [==============================] - 45s 363ms/step - loss: 0.0696 - acc: 0.9766 - val_loss: 0.1359 - val_acc: 0.9292
# Epoch 28/30
# 125/125 [==============================] - 46s 366ms/step - loss: 0.0652 - acc: 0.9774 - val_loss: 0.1045 - val_acc: 0.9604
# Epoch 29/30
# 125/125 [==============================] - 46s 367ms/step - loss: 0.0673 - acc: 0.9726 - val_loss: 0.0776 - val_acc: 0.9646
# Epoch 30/30
# 125/125 [==============================] - 45s 362ms/step - loss: 0.0666 - acc: 0.9771 - val_loss: 0.1051 - val_acc: 0.9542

# %% [markdown]
# ##Evaluation

# %%
loss, acc = model3.evaluate(train_images, train_y)
print("Train loss: {}\nTrain accuracy: {:.1f}%".format(loss, acc * 100))

print()
loss, acc = model3.evaluate(test_images, test_y)
print("Test loss: {}\nTest accuracy: {:.1f}%".format(loss, acc * 100))
# Out:
# 147/147 [==============================] - 1s 10ms/step - loss: 0.0459 - acc: 0.9853
# Train loss: 0.045925322920084
# Train accuracy: 98.5%
#
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0664 - acc: 0.9726
# Test loss: 0.06643440574407578
# Test accuracy: 97.3%

# %% [markdown]
# The dropout layers added 0.5% to the performance of the model with same even with fewer epochs.  It improved the model slightly and is now our prefered model.

# %% [markdown]
# ##Save Model

# %%
model3.save('/content/drive/MyDrive/chest_xray/chest_xray_cnn_dropout2_100_801010.h5')


f = open('/content/drive/MyDrive/chest_xray/history3.pkl', 'wb')
pickle.dump(history3.history, f)

# with open('content/drive/MyDrive/chest_xray/hist3.pkl', 'rb') as f:
#     history3 = pickle.load(f)

# %% [markdown]
# # <font color='green'>Model 4: CNN Dropout with Cropped Images</font>
# During EDA on images, it was clear that there are unnecessary edges on all of our images.  After looking at a handful of images, I decided I could cut off 10px on every side of image and not sacrifice any lung pixels.

# %% [markdown]
# ## Crop images

# %% [markdown]
# I ended up cropping it to 128px instead to so I could add one more layer to my model.

# %%
# crop down images as experiment
print(train_images[0].shape)
crop_train_images = np.array([x[6:134, 11:139, :] for x in train_images]) # height, width, channels
print(crop_train_images[0].shape)

crop_test_images = np.array([x[6:134, 11:139, :] for x in test_images])

crop_val_images = np.array([x[6:134, 11:139, :] for x in val_images])
# Out:
# (150, 150, 3)
# (128, 128, 3)

# %%
orig_px = int(train_images[0].shape[0] ** 2)
crop_px = int(crop_train_images[0].shape[0] ** 2)

print('original image size: {} px'.format(orig_px))
print('reduced image size: {} px'.format(crop_px))

print('reduction: {:.1f}%'.format((orig_px-crop_px)/orig_px*100))
# Out:
# original image size: 22500 px
# reduced image size: 16384 px
# reduction: 27.2%

# %% [markdown]
# ## Build Model

# %% [markdown]
# Dropout strategy did not work on the cropped images.  Smaller images combined with dropout left less raw data to start with.
#
# On the bright side, this model ran very quickly.

# %%
# I want to try a dropout strategy.  Not sure if it applies here
# Way faster.  Tried different kernel sizes, and nodes

model4 = models.Sequential()

model4.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(128, 128, 3)))
model4.add(layers.MaxPooling2D((2, 2)))


model4.add(layers.Conv2D(64, (3, 3), activation='relu'))
model4.add(layers.MaxPooling2D((2, 2)))

model4.add(layers.Conv2D(64, (3, 3), activation='relu'))
model4.add(layers.MaxPooling2D((2, 2)))


model4.add(layers.Conv2D(128, (3, 3), activation='relu'))
model4.add(layers.MaxPooling2D((2, 2)))


model4.add(layers.Conv2D(128, (3, 3), activation='relu'))
model4.add(layers.MaxPooling2D((2, 2)))
#model4.add(SpatialDropout2D(0.2))



# cannot add another layer unless I up the image size, MaxPools are shrinking outputs by 1/2

model4.add(layers.Flatten())
model4.add(layers.Dense(512, activation='relu'))
model4.add(layers.Dense(1, activation='sigmoid'))

# %%
model4.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %% [markdown]
# ## Train Model
# Reduced the number of epochs and implemented dropout layers to hopefully prevent overfitting which appears to occur around 60 or 70 epochs in.

# %%
history4 = model4.fit(crop_train_images,  
                        train_y,
                        #batch_size=32,
                        steps_per_epoch=130, 
                        epochs=31, 
                        validation_data=(crop_val_images, val_y), 
                        validation_steps=16)
# Out:
# Epoch 1/31
# 130/130 [==============================] - 2s 19ms/step - loss: 0.5365 - acc: 0.7567 - val_loss: 0.4043 - val_acc: 0.8730
# Epoch 2/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.3949 - acc: 0.8203 - val_loss: 0.3091 - val_acc: 0.8926
# Epoch 3/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.3439 - acc: 0.8418 - val_loss: 0.2751 - val_acc: 0.8730
# Epoch 4/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.3168 - acc: 0.8648 - val_loss: 0.2338 - val_acc: 0.9062
# Epoch 5/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.2743 - acc: 0.8853 - val_loss: 0.2614 - val_acc: 0.8828
# Epoch 6/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.2598 - acc: 0.8889 - val_loss: 0.1862 - val_acc: 0.9160
# Epoch 7/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.2155 - acc: 0.9109 - val_loss: 0.1852 - val_acc: 0.9277
# Epoch 8/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.2066 - acc: 0.9191 - val_loss: 0.1596 - val_acc: 0.9336
# Epoch 9/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1780 - acc: 0.9288 - val_loss: 0.1459 - val_acc: 0.9434
# Epoch 10/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1636 - acc: 0.9362 - val_loss: 0.1391 - val_acc: 0.9395
# Epoch 11/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1605 - acc: 0.9365 - val_loss: 0.1441 - val_acc: 0.9375
# Epoch 12/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1474 - acc: 0.9459 - val_loss: 0.1322 - val_acc: 0.9395
# Epoch 13/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1369 - acc: 0.9459 - val_loss: 0.1379 - val_acc: 0.9434
# Epoch 14/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1322 - acc: 0.9483 - val_loss: 0.1538 - val_acc: 0.9434
# Epoch 15/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1239 - acc: 0.9541 - val_loss: 0.1332 - val_acc: 0.9473
# Epoch 16/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1201 - acc: 0.9539 - val_loss: 0.1132 - val_acc: 0.9512
# Epoch 17/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1174 - acc: 0.9563 - val_loss: 0.1094 - val_acc: 0.9590
# Epoch 18/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1150 - acc: 0.9567 - val_loss: 0.1144 - val_acc: 0.9492
# Epoch 19/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1062 - acc: 0.9623 - val_loss: 0.1050 - val_acc: 0.9551
# Epoch 20/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.1004 - acc: 0.9621 - val_loss: 0.1074 - val_acc: 0.9531
# Epoch 21/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0979 - acc: 0.9628 - val_loss: 0.1065 - val_acc: 0.9512
# Epoch 22/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0992 - acc: 0.9609 - val_loss: 0.1919 - val_acc: 0.9160
# Epoch 23/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0856 - acc: 0.9693 - val_loss: 0.1339 - val_acc: 0.9473
# Epoch 24/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0900 - acc: 0.9679 - val_loss: 0.0947 - val_acc: 0.9570
# Epoch 25/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0879 - acc: 0.9655 - val_loss: 0.0922 - val_acc: 0.9570
# Epoch 26/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0775 - acc: 0.9697 - val_loss: 0.0955 - val_acc: 0.9570
# Epoch 27/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0802 - acc: 0.9715 - val_loss: 0.0957 - val_acc: 0.9551
# Epoch 28/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0725 - acc: 0.9737 - val_loss: 0.0907 - val_acc: 0.9551
# Epoch 29/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0659 - acc: 0.9746 - val_loss: 0.1065 - val_acc: 0.9473
# Epoch 30/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0697 - acc: 0.9754 - val_loss: 0.0871 - val_acc: 0.9570
# Epoch 31/31
# 130/130 [==============================] - 2s 18ms/step - loss: 0.0567 - acc: 0.9783 - val_loss: 0.0902 - val_acc: 0.9570

# %% [markdown]
# ##Evaluate Model

# %%
# same inverse problem as before
loss, acc = model4.evaluate(crop_train_images, train_y)
print("Train loss: {}\nTrain accuracy: {}".format(loss, acc))

print()
loss, acc = model4.evaluate(crop_test_images, test_y)
print("Test loss: {}\nTest accuracy: {}".format(loss, acc))
# Out:
# 147/147 [==============================] - 1s 7ms/step - loss: 0.0414 - acc: 0.9863
# Train loss: 0.04144984483718872
# Train accuracy: 0.9863393902778625
#
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0767 - acc: 0.9675
# Test loss: 0.07669904828071594
# Test accuracy: 0.9675213694572449

# %% [markdown]
# 97% was the best I could tune it using the hyperparameters.
# This model performed almost identically to CNN Dropout but was much quicker.
#
# I found I could reduce the image further, but 128px allowed me to do the same number of Pooling layers as previous model, so I did not go below this.

# %%
model4.save('/content/drive/MyDrive/chest_xray/chest_xray_cnn_crop_100_801010.h5')

# %% [markdown]
# # <font color='green'>Model 5: Image Augmentation</font>
# This will be the 5th and final model.  Adding image augmentation to the mix.
#
# This method was attempted on 50% of the data, and took too long to run.  It is likely a good method for much smaller data set.  I leave it here as an example for future projects

# %%
# I want to try a dropout strategy.  Not sure if it applies here

model5 = models.Sequential()


model5.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model5.add(layers.MaxPooling2D((2, 2)))
model5.add(layers.Conv2D(64, (3, 3), activation='relu'))
model5.add(layers.MaxPooling2D((2, 2)))
model5.add(layers.Conv2D(128, (3, 3), activation='relu'))
model5.add(layers.MaxPooling2D((2, 2)))
model5.add(layers.Flatten())
model5.add(layers.Dense(512, activation='relu'))
model5.add(layers.Dense(1, activation='sigmoid'))

# %%
model5.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
train_datagen = ImageDataGenerator(rotation_range=10, 
                                   width_shift_range=0.2, 
                                   height_shift_range=0.2, 
                                   shear_range=0.2, 
                                   brightness_range=[0.8,1.2]
                                   zoom_range=0.2, 
                                   horizontal_flip=False, 
                                   fill_mode='nearest'
                                   
                                   )

# same test_datagen from previous models.  Just repeated in case not cached.
test_datagen = ImageDataGenerator(rescale=1./255)

# This is the same train_generator from previous models
train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_folder,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=32,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(val_folder, 
                                                        target_size=(150, 150), 
                                                        batch_size=32, 
                                                        class_mode='binary')
# Out:
# Found 4685 images belonging to 2 classes.
# Found 585 images belonging to 2 classes.

# %%
history5 = model5.fit_generator(train_generator, 
                              steps_per_epoch=50, 
                              epochs=20, 
                              validation_data=validation_generator, 
                              validation_steps=15)

# %% [markdown]
# This configuration did not improve the results, but may be acceptable for smaller datasets.

# %%
# save to google drive
model5.save('/content/drive/MyDrive/chest_xray/chest_xray_augCNN_100_801010.h5')

# %%
loss, acc = model5.evaluate(train_images, train_y)
print("Train loss: {}\nTrain accuracy: {}".format(loss, acc))

print()
loss, acc = model5.evaluate(test_images, test_y)
print("Test loss: {}\nTest accuracy: {}".format(loss, acc))

# %% [markdown]
# # <font color='green'>Best Model (CNN with Dropout)</font>

# %% [markdown]
# ## Load Model
#
# Load and test the best model.
# Also load other necessary files for evaluation.
#
# Model 3, CNN with Dropout performed the best for us when measured for accuracy.

# %%
# To load up the pickled image datasets, run this block
import pickle

my_file = "/content/drive/MyDrive/chest_xray/big_image_sets.pkl"
with open(my_file, "rb") as f:
     test_images, test_labels, val_images, val_labels, train_images, train_labels = pickle.load(f)

# %%
# I am only using this code to grab the shape of the images (how many images do I have?)

train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (4685, 67500)
# (585, 67500)
# (585, 67500)

# %%
# use labels[: 1] so that we have pneumonia as 1 and normal as 0
train_y = np.reshape(train_labels[:,1], (train_img.shape[0],1))
test_y = np.reshape(test_labels[:,1], (test_img.shape[0],1))
val_y = np.reshape(val_labels[:,1], (val_img.shape[0],1))

# %%
import pickle
# we can now load the saved model

model_path = '/content/drive/MyDrive/chest_xray/best_model.h5'
my_model = load_model(model_path)

with open('/content/drive/MyDrive/chest_xray/history2.pkl', 'rb') as f:
    my_history = pickle.load(f)

# %%
my_model.history

# %% [markdown]
# I plan on productionizing the model, and want to test it out in the same way it will be used in the app.  This bit of code iterates through my test images and evaluates them.  If they match, they get a smiley.  We should see lots of smileys and very few X's.

# %% [markdown]
# ## Production Model Testing

# %%
def model_testing(my_model, images, labels, show_results=True):
  '''
  Prints out the evaluated result of each image (binary clasification model)

  Parameters
  images (list): 
  '''
  correct = 0
  incorrect = 0
  incorrect_images = []

  if show_results: print("{:12}{:12}{:12}{:12}".format('Label', 'Prediction', 'Float', 'Correct?'))

  # go through some images and predict them individually.
  for i in range(len(images)):
    img_orig = images[i]
    img = img_orig.reshape(-1, 150,150, 3)

    #print(type(test_labels[i][0]))
    if labels[i][1] > 0:
      image_label = 'NORMAL'
    else:
      image_label = 'PNEUMONIA'

    result = my_model.predict(img)
    pred_float = result[0][0]

    if result[0].round() > 0:
      prediction = 'NORMAL'
    else:
      prediction = 'PNEUMONIA'  
    

    if show_results: print('{:>4}: {:12}{:12}{:<12.2f}'.format(i, image_label, prediction, pred_float), end=' ')

    if prediction == image_label:
      correct += 1
      if show_results: print("\U0001F603") 
    else:
      incorrect += 1
      if show_results: print(u'\u274C')
      incorrect_images.append([i, img_orig, prediction, pred_float, image_label])

  print('Correct: {}'.format(correct))
  print('Incorrect: {}'.format(incorrect))

  print(correct / (correct + incorrect))
  return incorrect_images


incorrect_images = model_testing(my_model, test_images, test_labels, show_results=True)
# Out:
# Label       Prediction  Float       Correct?
#    0: PNEUMONIA   PNEUMONIA   0.05         😃
#    1: PNEUMONIA   PNEUMONIA   0.00         😃
#    2: NORMAL      NORMAL      1.00         😃
#    3: PNEUMONIA   PNEUMONIA   0.01         😃
#    4: NORMAL      NORMAL      1.00         😃
#    5: NORMAL      NORMAL      1.00         😃
#    6: NORMAL      NORMAL      1.00         😃
#    7: NORMAL      NORMAL      1.00         😃
#    8: PNEUMONIA   PNEUMONIA   0.00         😃
#    9: NORMAL      NORMAL      0.64         😃
#   10: NORMAL      NORMAL      1.00         😃
#   11: NORMAL      NORMAL      1.00         😃
#   12: NORMAL      NORMAL      1.00         😃
#   13: NORMAL      NORMAL      1.00         😃
#   14: NORMAL      NORMAL      1.00         😃
#   15: NORMAL      NORMAL      1.00         😃
#   16: NORMAL      NORMAL      1.00         😃
#   17: PNEUMONIA   PNEUMONIA   0.25         😃
#   18: NORMAL      NORMAL      1.00         😃
#   19: PNEUMONIA   PNEUMONIA   0.39         😃
#   20: NORMAL      NORMAL      1.00         😃
#   21: NORMAL      NORMAL      1.00         😃
#   22: NORMAL      NORMAL      0.97         😃
#   23: NORMAL      NORMAL      0.99         😃
#   24: NORMAL      NORMAL      1.00         😃
#   25: NORMAL      NORMAL      1.00         😃
#   26: PNEUMONIA   PNEUMONIA   0.00         😃
#   27: NORMAL      NORMAL      1.00         😃
#   28: PNEUMONIA   PNEUMONIA   0.00         😃
#   29: NORMAL      NORMAL      0.99         😃
#   30: PNEUMONIA   PNEUMONIA   0.00         😃
#   31: PNEUMONIA   PNEUMONIA   0.16         😃
#   32: NORMAL      NORMAL      0.93         😃
#   33: NORMAL      NORMAL      0.99         😃
#   34: NORMAL      NORMAL      1.00         😃
#   35: PNEUMONIA   PNEUMONIA   0.00         😃
#   36: NORMAL      NORMAL      1.00         😃
#   37: NORMAL      PNEUMONIA   0.42         ❌
#   38: NORMAL      NORMAL      0.99         😃
#   39: PNEUMONIA   PNEUMONIA   0.06         😃
#   40: PNEUMONIA   PNEUMONIA   0.01         😃
#   41: NORMAL      NORMAL      1.00         😃
#   42: PNEUMONIA   PNEUMONIA   0.14         😃
#   43: NORMAL      NORMAL      0.50         😃
#   44: PNEUMONIA   PNEUMONIA   0.06         😃
#   45: NORMAL      NORMAL      1.00         😃
#   46: PNEUMONIA   PNEUMONIA   0.02         😃
#   47: PNEUMONIA   PNEUMONIA   0.01         😃
#   48: NORMAL      NORMAL      1.00         😃
#   49: NORMAL      NORMAL      0.94         😃
#   50: NORMAL      NORMAL      1.00         😃
#   51: NORMAL      NORMAL      1.00         😃
#   52: NORMAL      NORMAL      1.00         😃
#   53: PNEUMONIA   PNEUMONIA   0.02         😃
#   54: NORMAL      NORMAL      1.00         😃
#   55: NORMAL      NORMAL      0.95         😃
#   56: NORMAL      NORMAL      1.00         😃
#   57: PNEUMONIA   PNEUMONIA   0.00         😃
#   58: NORMAL      NORMAL      1.00         😃
#   59: NORMAL      NORMAL      0.84         😃
#   60: NORMAL      NORMAL      1.00         😃
#   61: NORMAL      NORMAL      1.00         😃
#   62: NORMAL      NORMAL      1.00         😃
#   63: NORMAL      NORMAL      1.00         😃
#   64: NORMAL      NORMAL      1.00         😃
#   65: NORMAL      NORMAL      0.97         😃
#   66: NORMAL      NORMAL      0.56         😃
#   67: NORMAL      NORMAL      1.00         😃
#   68: NORMAL      NORMAL      1.00         😃
#   69: NORMAL      NORMAL      1.00         😃
#   70: NORMAL      NORMAL      1.00         😃
#   71: PNEUMONIA   PNEUMONIA   0.00         😃
#   72: PNEUMONIA   PNEUMONIA   0.41         😃
#   73: NORMAL      NORMAL      1.00         😃
#   74: NORMAL      NORMAL      0.93         😃
#   75: NORMAL      NORMAL      1.00         😃
#   76: NORMAL      NORMAL      0.99         😃
#   77: NORMAL      NORMAL      1.00         😃
#   78: PNEUMONIA   PNEUMONIA   0.00         😃
#   79: PNEUMONIA   PNEUMONIA   0.02         😃
#   80: NORMAL      NORMAL      1.00         😃
#   81: NORMAL      NORMAL      0.86         😃
#   82: NORMAL      NORMAL      1.00         😃
#   83: PNEUMONIA   PNEUMONIA   0.02         😃
#   84: NORMAL      NORMAL      1.00         😃
#   85: PNEUMONIA   NORMAL      0.92         ❌
#   86: NORMAL      NORMAL      1.00         😃
#   87: PNEUMONIA   PNEUMONIA   0.00         😃
#   88: NORMAL      NORMAL      1.00         😃
#   89: NORMAL      NORMAL      1.00         😃
#   90: PNEUMONIA   PNEUMONIA   0.32         😃
#   91: PNEUMONIA   PNEUMONIA   0.03         😃
#   92: NORMAL      NORMAL      1.00         😃
#   93: NORMAL      NORMAL      0.99         😃
#   94: NORMAL      NORMAL      0.99         😃
#   95: PNEUMONIA   PNEUMONIA   0.00         😃
#   96: NORMAL      NORMAL      1.00         😃
#   97: NORMAL      NORMAL      0.99         😃
#   98: NORMAL      NORMAL      0.99         😃
#   99: NORMAL      NORMAL      1.00         😃
#  100: PNEUMONIA   PNEUMONIA   0.00         😃
#  101: NORMAL      NORMAL      1.00         😃
#  102: NORMAL      NORMAL      0.99         😃
#  103: NORMAL      NORMAL      1.00         😃
#  104: PNEUMONIA   PNEUMONIA   0.00         😃
#  105: NORMAL      NORMAL      1.00         😃
#  106: PNEUMONIA   PNEUMONIA   0.00         😃
#  107: NORMAL      NORMAL      1.00         😃
#  108: NORMAL      NORMAL      1.00         😃
#  109: PNEUMONIA   PNEUMONIA   0.01         😃
#  110: NORMAL      NORMAL      1.00         😃
#  111: NORMAL      NORMAL      1.00         😃
#  112: PNEUMONIA   PNEUMONIA   0.00         😃
#  113: NORMAL      PNEUMONIA   0.13         ❌
#  114: NORMAL      NORMAL      0.99         😃
#  115: NORMAL      NORMAL      1.00         😃
#  116: PNEUMONIA   PNEUMONIA   0.00         😃
#  117: NORMAL      NORMAL      1.00         😃
#  118: NORMAL      NORMAL      1.00         😃
#  119: NORMAL      NORMAL      1.00         😃
#  120: NORMAL      NORMAL      1.00         😃
#  121: NORMAL      NORMAL      0.99         😃
#  122: NORMAL      NORMAL      1.00         😃
#  123: NORMAL      NORMAL      1.00         😃
#  124: PNEUMONIA   PNEUMONIA   0.27         😃
#  125: NORMAL      NORMAL      1.00         😃
#  126: NORMAL      NORMAL      0.94         😃
#  127: NORMAL      NORMAL      1.00         😃
#  128: NORMAL      NORMAL      1.00         😃
#  129: NORMAL      NORMAL      1.00         😃
#  130: PNEUMONIA   PNEUMONIA   0.27         😃
#  131: NORMAL      NORMAL      1.00         😃
#  132: NORMAL      NORMAL      1.00         😃
#  133: NORMAL      NORMAL      0.98         😃
#  134: NORMAL      NORMAL      0.84         😃
#  135: NORMAL      NORMAL      1.00         😃
#  136: NORMAL      NORMAL      0.99         😃
#  137: NORMAL      NORMAL      1.00         😃
#  138: PNEUMONIA   PNEUMONIA   0.01         😃
#  139: NORMAL      NORMAL      1.00         😃
#  140: NORMAL      NORMAL      1.00         😃
#  141: NORMAL      NORMAL      1.00         😃
#  142: NORMAL      NORMAL      1.00         😃
#  143: PNEUMONIA   PNEUMONIA   0.00         😃
#  144: PNEUMONIA   PNEUMONIA   0.00         😃
#  145: NORMAL      NORMAL      1.00         😃
#  146: NORMAL      NORMAL      1.00         😃
#  147: NORMAL      NORMAL      1.00         😃
#  148: NORMAL      NORMAL      1.00         😃
#  149: PNEUMONIA   PNEUMONIA   0.02         😃
#  150: NORMAL      NORMAL      1.00         😃
#  151: NORMAL      NORMAL      0.54         😃
#  152: NORMAL      NORMAL      1.00         😃
#  153: NORMAL      NORMAL      0.95         😃
#  154: NORMAL      NORMAL      1.00         😃
#  155: PNEUMONIA   PNEUMONIA   0.00         😃
#  156: PNEUMONIA   PNEUMONIA   0.00         😃
#  157: PNEUMONIA   PNEUMONIA   0.04         😃
#  158: NORMAL      NORMAL      1.00         😃
#  159: NORMAL      NORMAL      1.00         😃
#  160: NORMAL      NORMAL      0.78         😃
#  161: NORMAL      NORMAL      1.00         😃
#  162: NORMAL      NORMAL      1.00         😃
#  163: NORMAL      NORMAL      1.00         😃
#  164: PNEUMONIA   PNEUMONIA   0.03         😃
#  165: NORMAL      NORMAL      1.00         😃
#  166: NORMAL      NORMAL      0.99         😃
#  167: PNEUMONIA   PNEUMONIA   0.00         😃
#  168: PNEUMONIA   PNEUMONIA   0.00         😃
#  169: NORMAL      NORMAL      1.00         😃
#  170: NORMAL      NORMAL      1.00         😃
#  171: PNEUMONIA   PNEUMONIA   0.00         😃
#  172: PNEUMONIA   PNEUMONIA   0.00         😃
#  173: NORMAL      NORMAL      1.00         😃
#  174: NORMAL      NORMAL      1.00         😃
#  175: NORMAL      NORMAL      1.00         😃
#  176: NORMAL      NORMAL      0.98         😃
#  177: NORMAL      NORMAL      1.00         😃
#  178: PNEUMONIA   PNEUMONIA   0.03         😃
#  179: NORMAL      NORMAL      1.00         😃
#  180: PNEUMONIA   PNEUMONIA   0.01         😃
#  181: NORMAL      NORMAL      1.00         😃
#  182: NORMAL      NORMAL      1.00         😃
#  183: PNEUMONIA   PNEUMONIA   0.02         😃
#  184: NORMAL      NORMAL      0.84         😃
#  185: PNEUMONIA   PNEUMONIA   0.00         😃
#  186: NORMAL      NORMAL      0.99         😃
#  187: PNEUMONIA   PNEUMONIA   0.06         😃
#  188: NORMAL      NORMAL      1.00         😃
#  189: NORMAL      NORMAL      1.00         😃
#  190: NORMAL      NORMAL      1.00         😃
#  191: PNEUMONIA   PNEUMONIA   0.00         😃
#  192: NORMAL      NORMAL      1.00         😃
#  193: PNEUMONIA   PNEUMONIA   0.00         😃
#  194: NORMAL      NORMAL      1.00         😃
#  195: NORMAL      NORMAL      1.00         😃
#  196: PNEUMONIA   PNEUMONIA   0.03         😃
#  197: NORMAL      NORMAL      0.98         😃
#  198: PNEUMONIA   PNEUMONIA   0.01         😃
#  199: NORMAL      NORMAL      1.00         😃
#  200: NORMAL      NORMAL      0.99         😃
#  201: NORMAL      NORMAL      1.00         😃
#  202: NORMAL      NORMAL      1.00         😃
#  203: NORMAL      NORMAL      0.99         😃
#  204: NORMAL      NORMAL      0.99         😃
#  205: NORMAL      NORMAL      1.00         😃
#  206: PNEUMONIA   PNEUMONIA   0.00         😃
#  207: NORMAL      NORMAL      0.97         😃
#  208: PNEUMONIA   PNEUMONIA   0.00         😃
#  209: NORMAL      NORMAL      1.00         😃
#  210: NORMAL      NORMAL      1.00         😃
#  211: NORMAL      NORMAL      1.00         😃
#  212: NORMAL      NORMAL      1.00         😃
#  213: NORMAL      NORMAL      1.00         😃
#  214: PNEUMONIA   PNEUMONIA   0.02         😃
#  215: NORMAL      NORMAL      0.98         😃
#  216: PNEUMONIA   PNEUMONIA   0.01         😃
#  217: NORMAL      NORMAL      1.00         😃
#  218: NORMAL      NORMAL      1.00         😃
#  219: NORMAL      NORMAL      1.00         😃
#  220: PNEUMONIA   PNEUMONIA   0.00         😃
#  221: PNEUMONIA   PNEUMONIA   0.01         😃
#  222: PNEUMONIA   PNEUMONIA   0.45         😃
#  223: NORMAL      NORMAL      1.00         😃
#  224: NORMAL      NORMAL      0.99         😃
#  225: NORMAL      NORMAL      0.70         😃
#  226: NORMAL      NORMAL      1.00         😃
#  227: NORMAL      NORMAL      1.00         😃
#  228: PNEUMONIA   PNEUMONIA   0.01         😃
#  229: NORMAL      NORMAL      1.00         😃
#  230: PNEUMONIA   PNEUMONIA   0.00         😃
#  231: NORMAL      NORMAL      1.00         😃
#  232: NORMAL      NORMAL      0.99         😃
#  233: PNEUMONIA   PNEUMONIA   0.00         😃
#  234: NORMAL      NORMAL      1.00         😃
#  235: NORMAL      NORMAL      0.95         😃
#  236: PNEUMONIA   PNEUMONIA   0.09         😃
#  237: NORMAL      NORMAL      1.00         😃
#  238: NORMAL      NORMAL      1.00         😃
#  239: NORMAL      NORMAL      0.99         😃
#  240: NORMAL      NORMAL      1.00         😃
#  241: NORMAL      NORMAL      1.00         😃
#  242: NORMAL      NORMAL      1.00         😃
#  243: NORMAL      NORMAL      0.89         😃
#  244: NORMAL      NORMAL      0.88         😃
#  245: NORMAL      NORMAL      1.00         😃
#  246: NORMAL      NORMAL      1.00         😃
#  247: PNEUMONIA   PNEUMONIA   0.00         😃
#  248: NORMAL      NORMAL      1.00         😃
#  249: NORMAL      NORMAL      1.00         😃
#  250: NORMAL      NORMAL      0.93         😃
#  251: NORMAL      NORMAL      1.00         😃
#  252: NORMAL      NORMAL      1.00         😃
#  253: NORMAL      NORMAL      1.00         😃
#  254: PNEUMONIA   PNEUMONIA   0.14         😃
#  255: PNEUMONIA   PNEUMONIA   0.00         😃
#  256: NORMAL      NORMAL      1.00         😃
#  257: NORMAL      NORMAL      1.00         😃
#  258: PNEUMONIA   PNEUMONIA   0.00         😃
#  259: PNEUMONIA   PNEUMONIA   0.04         😃
#  260: PNEUMONIA   PNEUMONIA   0.01         😃
#  261: PNEUMONIA   PNEUMONIA   0.00         😃
#  262: NORMAL      NORMAL      0.97         😃
#  263: PNEUMONIA   NORMAL      0.95         ❌
#  264: NORMAL      NORMAL      0.99         😃
#  265: NORMAL      NORMAL      0.99         😃
#  266: NORMAL      NORMAL      1.00         😃
#  267: NORMAL      NORMAL      1.00         😃
#  268: PNEUMONIA   NORMAL      0.94         ❌
#  269: NORMAL      NORMAL      1.00         😃
#  270: PNEUMONIA   PNEUMONIA   0.00         😃
#  271: NORMAL      NORMAL      1.00         😃
#  272: NORMAL      NORMAL      1.00         😃
#  273: NORMAL      NORMAL      1.00         😃
#  274: PNEUMONIA   PNEUMONIA   0.05         😃
#  275: NORMAL      NORMAL      1.00         😃
#  276: NORMAL      NORMAL      1.00         😃
#  277: PNEUMONIA   PNEUMONIA   0.02         😃
#  278: NORMAL      NORMAL      1.00         😃
#  279: PNEUMONIA   PNEUMONIA   0.01         😃
#  280: NORMAL      NORMAL      1.00         😃
#  281: PNEUMONIA   PNEUMONIA   0.00         😃
#  282: NORMAL      NORMAL      1.00         😃
#  283: PNEUMONIA   PNEUMONIA   0.00         😃
#  284: NORMAL      NORMAL      1.00         😃
#  285: NORMAL      NORMAL      1.00         😃
#  286: NORMAL      NORMAL      1.00         😃
#  287: NORMAL      NORMAL      1.00         😃
#  288: NORMAL      NORMAL      1.00         😃
#  289: NORMAL      NORMAL      1.00         😃
#  290: NORMAL      NORMAL      1.00         😃
#  291: PNEUMONIA   PNEUMONIA   0.20         😃
#  292: NORMAL      NORMAL      0.86         😃
#  293: NORMAL      NORMAL      0.99         😃
#  294: PNEUMONIA   PNEUMONIA   0.03         😃
#  295: NORMAL      NORMAL      1.00         😃
#  296: NORMAL      NORMAL      1.00         😃
#  297: NORMAL      NORMAL      0.76         😃
#  298: NORMAL      NORMAL      0.99         😃
#  299: PNEUMONIA   PNEUMONIA   0.00         😃
#  300: PNEUMONIA   PNEUMONIA   0.04         😃
#  301: NORMAL      NORMAL      1.00         😃
#  302: NORMAL      NORMAL      0.90         😃
#  303: NORMAL      NORMAL      1.00         😃
#  304: NORMAL      NORMAL      1.00         😃
#  305: NORMAL      NORMAL      1.00         😃
#  306: PNEUMONIA   PNEUMONIA   0.01         😃
#  307: NORMAL      NORMAL      1.00         😃
#  308: PNEUMONIA   NORMAL      0.91         ❌
#  309: NORMAL      NORMAL      1.00         😃
#  310: NORMAL      NORMAL      1.00         😃
#  311: NORMAL      NORMAL      1.00         😃
#  312: NORMAL      NORMAL      0.82         😃
#  313: NORMAL      NORMAL      1.00         😃
#  314: PNEUMONIA   NORMAL      0.91         ❌
#  315: NORMAL      NORMAL      0.93         😃
#  316: NORMAL      NORMAL      1.00         😃
#  317: NORMAL      NORMAL      1.00         😃
#  318: NORMAL      NORMAL      1.00         😃
#  319: NORMAL      NORMAL      0.99         😃
#  320: NORMAL      NORMAL      1.00         😃
#  321: NORMAL      NORMAL      1.00         😃
#  322: NORMAL      NORMAL      1.00         😃
#  323: PNEUMONIA   PNEUMONIA   0.37         😃
#  324: NORMAL      NORMAL      1.00         😃
#  325: PNEUMONIA   PNEUMONIA   0.04         😃
#  326: NORMAL      NORMAL      1.00         😃
#  327: NORMAL      NORMAL      1.00         😃
#  328: PNEUMONIA   PNEUMONIA   0.32         😃
#  329: NORMAL      NORMAL      0.80         😃
#  330: NORMAL      NORMAL      0.88         😃
#  331: NORMAL      NORMAL      1.00         😃
#  332: NORMAL      NORMAL      1.00         😃
#  333: NORMAL      NORMAL      1.00         😃
#  334: NORMAL      NORMAL      0.63         😃
#  335: NORMAL      NORMAL      1.00         😃
#  336: PNEUMONIA   PNEUMONIA   0.01         😃
#  337: NORMAL      NORMAL      0.99         😃
#  338: NORMAL      NORMAL      1.00         😃
#  339: NORMAL      NORMAL      1.00         😃
#  340: NORMAL      NORMAL      1.00         😃
#  341: PNEUMONIA   PNEUMONIA   0.00         😃
#  342: NORMAL      NORMAL      0.99         😃
#  343: NORMAL      NORMAL      1.00         😃
#  344: NORMAL      NORMAL      1.00         😃
#  345: NORMAL      NORMAL      1.00         😃
#  346: PNEUMONIA   PNEUMONIA   0.00         😃
#  347: PNEUMONIA   PNEUMONIA   0.05         😃
#  348: PNEUMONIA   PNEUMONIA   0.01         😃
#  349: NORMAL      NORMAL      1.00         😃
#  350: NORMAL      NORMAL      1.00         😃
#  351: NORMAL      NORMAL      1.00         😃
#  352: NORMAL      NORMAL      0.99         😃
#  353: NORMAL      NORMAL      1.00         😃
#  354: NORMAL      NORMAL      1.00         😃
#  355: NORMAL      NORMAL      1.00         😃
#  356: PNEUMONIA   PNEUMONIA   0.01         😃
#  357: NORMAL      NORMAL      0.99         😃
#  358: PNEUMONIA   PNEUMONIA   0.01         😃
#  359: NORMAL      NORMAL      1.00         😃
#  360: NORMAL      NORMAL      1.00         😃
#  361: NORMAL      NORMAL      0.98         😃
#  362: NORMAL      NORMAL      1.00         😃
#  363: NORMAL      NORMAL      0.99         😃
#  364: NORMAL      NORMAL      1.00         😃
#  365: NORMAL      NORMAL      1.00         😃
#  366: NORMAL      NORMAL      1.00         😃
#  367: NORMAL      NORMAL      1.00         😃
#  368: NORMAL      NORMAL      1.00         😃
#  369: NORMAL      NORMAL      1.00         😃
#  370: NORMAL      NORMAL      1.00         😃
#  371: NORMAL      NORMAL      1.00         😃
#  372: NORMAL      NORMAL      0.99         😃
#  373: NORMAL      NORMAL      1.00         😃
#  374: NORMAL      NORMAL      1.00         😃
#  375: PNEUMONIA   PNEUMONIA   0.00         😃
#  376: PNEUMONIA   PNEUMONIA   0.00         😃
#  377: NORMAL      NORMAL      1.00         😃
#  378: PNEUMONIA   PNEUMONIA   0.01         😃
#  379: NORMAL      NORMAL      1.00         😃
#  380: PNEUMONIA   PNEUMONIA   0.09         😃
#  381: NORMAL      NORMAL      1.00         😃
#  382: PNEUMONIA   PNEUMONIA   0.00         😃
#  383: NORMAL      NORMAL      1.00         😃
#  384: NORMAL      NORMAL      1.00         😃
#  385: PNEUMONIA   PNEUMONIA   0.00         😃
#  386: PNEUMONIA   PNEUMONIA   0.02         😃
#  387: NORMAL      NORMAL      1.00         😃
#  388: NORMAL      NORMAL      1.00         😃
#  389: NORMAL      NORMAL      1.00         😃
#  390: NORMAL      NORMAL      1.00         😃
#  391: NORMAL      NORMAL      0.99         😃
#  392: NORMAL      NORMAL      1.00         😃
#  393: PNEUMONIA   PNEUMONIA   0.00         😃
#  394: NORMAL      NORMAL      1.00         😃
#  395: NORMAL      NORMAL      1.00         😃
#  396: PNEUMONIA   PNEUMONIA   0.00         😃
#  397: NORMAL      NORMAL      1.00         😃
#  398: PNEUMONIA   PNEUMONIA   0.02         😃
#  399: PNEUMONIA   PNEUMONIA   0.00         😃
#  400: NORMAL      NORMAL      1.00         😃
#  401: NORMAL      NORMAL      1.00         😃
#  402: NORMAL      NORMAL      1.00         😃
#  403: NORMAL      NORMAL      0.98         😃
#  404: PNEUMONIA   PNEUMONIA   0.01         😃
#  405: NORMAL      NORMAL      0.74         😃
#  406: NORMAL      NORMAL      0.99         😃
#  407: NORMAL      NORMAL      1.00         😃
#  408: NORMAL      NORMAL      1.00         😃
#  409: NORMAL      NORMAL      1.00         😃
#  410: NORMAL      NORMAL      1.00         😃
#  411: NORMAL      NORMAL      1.00         😃
#  412: NORMAL      NORMAL      1.00         😃
#  413: NORMAL      NORMAL      1.00         😃
#  414: NORMAL      NORMAL      1.00         😃
#  415: NORMAL      NORMAL      1.00         😃
#  416: PNEUMONIA   PNEUMONIA   0.10         😃
#  417: NORMAL      NORMAL      1.00         😃
#  418: NORMAL      NORMAL      1.00         😃
#  419: NORMAL      NORMAL      1.00         😃
#  420: NORMAL      NORMAL      1.00         😃
#  421: NORMAL      NORMAL      1.00         😃
#  422: NORMAL      NORMAL      1.00         😃
#  423: NORMAL      NORMAL      1.00         😃
#  424: NORMAL      NORMAL      1.00         😃
#  425: PNEUMONIA   PNEUMONIA   0.36         😃
#  426: NORMAL      NORMAL      1.00         😃
#  427: NORMAL      NORMAL      0.99         😃
#  428: PNEUMONIA   PNEUMONIA   0.00         😃
#  429: NORMAL      NORMAL      1.00         😃
#  430: NORMAL      NORMAL      1.00         😃
#  431: NORMAL      NORMAL      1.00         😃
#  432: NORMAL      NORMAL      1.00         😃
#  433: NORMAL      NORMAL      0.99         😃
#  434: NORMAL      NORMAL      1.00         😃
#  435: NORMAL      NORMAL      0.98         😃
#  436: NORMAL      NORMAL      1.00         😃
#  437: NORMAL      NORMAL      1.00         😃
#  438: NORMAL      NORMAL      0.82         😃
#  439: PNEUMONIA   PNEUMONIA   0.00         😃
#  440: NORMAL      NORMAL      0.82         😃
#  441: NORMAL      NORMAL      1.00         😃
#  442: NORMAL      NORMAL      1.00         😃
#  443: NORMAL      NORMAL      1.00         😃
#  444: NORMAL      NORMAL      1.00         😃
#  445: NORMAL      NORMAL      1.00         😃
#  446: NORMAL      NORMAL      1.00         😃
#  447: NORMAL      NORMAL      1.00         😃
#  448: NORMAL      NORMAL      1.00         😃
#  449: NORMAL      NORMAL      0.99         😃
#  450: NORMAL      NORMAL      1.00         😃
#  451: PNEUMONIA   PNEUMONIA   0.00         😃
#  452: PNEUMONIA   PNEUMONIA   0.00         😃
#  453: NORMAL      NORMAL      1.00         😃
#  454: NORMAL      NORMAL      1.00         😃
#  455: NORMAL      NORMAL      1.00         😃
#  456: NORMAL      NORMAL      1.00         😃
#  457: NORMAL      NORMAL      1.00         😃
#  458: PNEUMONIA   PNEUMONIA   0.03         😃
#  459: PNEUMONIA   PNEUMONIA   0.00         😃
#  460: NORMAL      NORMAL      0.99         😃
#  461: NORMAL      NORMAL      1.00         😃
#  462: NORMAL      NORMAL      1.00         😃
#  463: PNEUMONIA   PNEUMONIA   0.02         😃
#  464: NORMAL      NORMAL      1.00         😃
#  465: PNEUMONIA   PNEUMONIA   0.07         😃
#  466: PNEUMONIA   PNEUMONIA   0.01         😃
#  467: NORMAL      NORMAL      1.00         😃
#  468: PNEUMONIA   PNEUMONIA   0.47         😃
#  469: PNEUMONIA   NORMAL      0.51         ❌
#  470: NORMAL      NORMAL      1.00         😃
#  471: NORMAL      NORMAL      1.00         😃
#  472: NORMAL      NORMAL      1.00         😃
#  473: NORMAL      NORMAL      1.00         😃
#  474: NORMAL      NORMAL      1.00         😃
#  475: NORMAL      PNEUMONIA   0.49         ❌
#  476: PNEUMONIA   PNEUMONIA   0.01         😃
#  477: NORMAL      NORMAL      1.00         😃
#  478: PNEUMONIA   PNEUMONIA   0.24         😃
#  479: NORMAL      NORMAL      1.00         😃
#  480: NORMAL      NORMAL      1.00         😃
#  481: NORMAL      NORMAL      1.00         😃
#  482: PNEUMONIA   PNEUMONIA   0.00         😃
#  483: PNEUMONIA   PNEUMONIA   0.23         😃
#  484: NORMAL      NORMAL      1.00         😃
#  485: NORMAL      NORMAL      1.00         😃
#  486: PNEUMONIA   PNEUMONIA   0.00         😃
#  487: NORMAL      NORMAL      1.00         😃
#  488: NORMAL      NORMAL      1.00         😃
#  489: NORMAL      NORMAL      1.00         😃
#  490: NORMAL      NORMAL      1.00         😃
#  491: NORMAL      NORMAL      1.00         😃
#  492: PNEUMONIA   PNEUMONIA   0.00         😃
#  493: NORMAL      NORMAL      1.00         😃
#  494: NORMAL      NORMAL      1.00         😃
#  495: NORMAL      NORMAL      1.00         😃
#  496: PNEUMONIA   PNEUMONIA   0.01         😃
#  497: NORMAL      NORMAL      0.99         😃
#  498: NORMAL      NORMAL      1.00         😃
#  499: NORMAL      NORMAL      1.00         😃
#  500: PNEUMONIA   PNEUMONIA   0.10         😃
#  501: NORMAL      NORMAL      1.00         😃
#  502: NORMAL      NORMAL      1.00         😃
#  503: NORMAL      NORMAL      0.95         😃
#  504: NORMAL      NORMAL      1.00         😃
#  505: PNEUMONIA   PNEUMONIA   0.07         😃
#  506: NORMAL      NORMAL      1.00         😃
#  507: NORMAL      NORMAL      1.00         😃
#  508: PNEUMONIA   PNEUMONIA   0.00         😃
#  509: NORMAL      NORMAL      0.99         😃
#  510: NORMAL      NORMAL      0.99         😃
#  511: NORMAL      NORMAL      1.00         😃
#  512: NORMAL      NORMAL      1.00         😃
#  513: NORMAL      NORMAL      1.00         😃
#  514: PNEUMONIA   PNEUMONIA   0.03         😃
#  515: NORMAL      NORMAL      0.96         😃
#  516: NORMAL      NORMAL      1.00         😃
#  517: NORMAL      NORMAL      1.00         😃
#  518: PNEUMONIA   PNEUMONIA   0.24         😃
#  519: PNEUMONIA   PNEUMONIA   0.00         😃
#  520: NORMAL      NORMAL      1.00         😃
#  521: NORMAL      NORMAL      1.00         😃
#  522: NORMAL      NORMAL      1.00         😃
#  523: NORMAL      NORMAL      1.00         😃
#  524: NORMAL      NORMAL      1.00         😃
#  525: NORMAL      NORMAL      1.00         😃
#  526: NORMAL      NORMAL      0.80         😃
#  527: PNEUMONIA   PNEUMONIA   0.00         😃
#  528: NORMAL      NORMAL      0.92         😃
#  529: PNEUMONIA   PNEUMONIA   0.01         😃
#  530: NORMAL      NORMAL      1.00         😃
#  531: NORMAL      NORMAL      1.00         😃
#  532: PNEUMONIA   PNEUMONIA   0.47         😃
#  533: NORMAL      NORMAL      0.98         😃
#  534: NORMAL      NORMAL      1.00         😃
#  535: NORMAL      NORMAL      0.99         😃
#  536: NORMAL      NORMAL      0.71         😃
#  537: NORMAL      NORMAL      1.00         😃
#  538: NORMAL      NORMAL      1.00         😃
#  539: NORMAL      NORMAL      0.99         😃
#  540: NORMAL      NORMAL      0.92         😃
#  541: NORMAL      NORMAL      1.00         😃
#  542: NORMAL      NORMAL      1.00         😃
#  543: PNEUMONIA   PNEUMONIA   0.23         😃
#  544: NORMAL      NORMAL      1.00         😃
#  545: PNEUMONIA   PNEUMONIA   0.50         😃
#  546: NORMAL      NORMAL      0.99         😃
#  547: NORMAL      NORMAL      0.89         😃
#  548: NORMAL      NORMAL      0.98         😃
#  549: NORMAL      NORMAL      1.00         😃
#  550: PNEUMONIA   PNEUMONIA   0.01         😃
#  551: PNEUMONIA   PNEUMONIA   0.00         😃
#  552: NORMAL      NORMAL      1.00         😃
#  553: NORMAL      NORMAL      1.00         😃
#  554: NORMAL      NORMAL      0.99         😃
#  555: PNEUMONIA   PNEUMONIA   0.07         😃
#  556: PNEUMONIA   PNEUMONIA   0.17         😃
#  557: NORMAL      NORMAL      1.00         😃
#  558: PNEUMONIA   PNEUMONIA   0.15         😃
#  559: PNEUMONIA   PNEUMONIA   0.00         😃
#  560: NORMAL      NORMAL      1.00         😃
#  561: PNEUMONIA   PNEUMONIA   0.01         😃
#  562: NORMAL      NORMAL      1.00         😃
#  563: NORMAL      NORMAL      1.00         😃
#  564: NORMAL      NORMAL      1.00         😃
#  565: PNEUMONIA   PNEUMONIA   0.02         😃
#  566: NORMAL      NORMAL      0.94         😃
#  567: PNEUMONIA   PNEUMONIA   0.01         😃
#  568: PNEUMONIA   PNEUMONIA   0.00         😃
#  569: NORMAL      NORMAL      1.00         😃
#  570: PNEUMONIA   PNEUMONIA   0.01         😃
#  571: PNEUMONIA   PNEUMONIA   0.01         😃
#  572: PNEUMONIA   PNEUMONIA   0.07         😃
#  573: NORMAL      NORMAL      1.00         😃
#  574: NORMAL      NORMAL      1.00         😃
#  575: NORMAL      NORMAL      1.00         😃
#  576: NORMAL      NORMAL      1.00         😃
#  577: NORMAL      PNEUMONIA   0.47         ❌
#  578: NORMAL      NORMAL      1.00         😃
#  579: NORMAL      NORMAL      1.00         😃
#  580: NORMAL      NORMAL      1.00         😃
#  581: PNEUMONIA   PNEUMONIA   0.02         😃
#  582: NORMAL      NORMAL      1.00         😃
#  583: NORMAL      NORMAL      0.98         😃
#  584: NORMAL      NORMAL      1.00         😃
# Correct: 575
# Incorrect: 10
# 0.9829059829059829

# %% [markdown]
# ##Miscategorized Images
# Characteristics of  images miscategorized by the model.
# - Mostly “Landscape” oriented (skinny lungs after resize)
# - Significant black edges compared to most images
# - Infants over represented
# - Numerical uncertainty by model
# - Blurry or low contrast images
# - Most can be corrected by image preprocessing (crop)

# %%
# What kind of misses did we get?
plt.style.use('seaborn-white')

for i, img, prediction, pred_float, result in incorrect_images:
  plt.imshow(img)
  plt.title("\nImage #{}\n Pred:{}, Actual:{}\nFloat:{:.2f}".format(i, prediction, result, pred_float))
  plt.show()

# %% [markdown]
# It is interesting to see the missed images.  Lots of infants.  Lots of pneumonia looking haze which was actualy vascular taking up a large portion of chest.  A few of them have faces showing where the mouth might be confused for a feature.  Most of the numerical predictions were not 0 or 1.  Perhaps a doctor could flag these results as inconclusive.

# %% [markdown]
# ## Best Model Performance

# %%
# CONFUSION MATRIX AND SCORING

preds = my_model.predict(test_images) # Use your best model. For CNN I used test_images, for baseline I used test_img
#acc = accuracy_score(test_y, np.round(preds))*100 
acc = (accuracy_score(test_y, np.round(preds)))*100  # my test_y is backwards for model2!!
cm = confusion_matrix(test_y, np.round(preds))
tn, fn, fp, tp = cm.ravel()

print('Confusion matrix')
print(cm)

print('\nMETRICS:')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {:.2f}%'.format(acc))
print('Precision: {:.2f}%'.format(precision))
print('Recall: {:.2f}%'.format(recall))
print('F1-score: {:.2f}'.format(2*precision*recall/(precision+recall)))
# Out:
# Confusion matrix
# [[152   6]
#  [  4 423]]
#
# METRICS:
# Accuracy: 98.29%
# Precision: 99.06%
# Recall: 98.60%
# F1-score: 98.83

# %%
sns.set_context('talk')
df_cm = pd.DataFrame(cm, columns=np.unique(test_y), index = np.unique(test_y))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (6,6))
plt.rcParams.update({'font.size': 60}) # font size for interior numbers


sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16}, fmt='g', cbar=False)# font size
plt.xticks([0.5, 1.5], ['Normal', 'Pneumonia'])
plt.yticks([0.3, 1.4], ['Normal', 'Pneumonia'])
plt.title('Chest X-ray Confusion Matrix')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/chest_xray/confusion_matrix.png', transparent=True)
sns.set_context('paper')

# %%
my_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               3211776
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The confusion matrix shows that the misses lean towards predicting pneumonia.  In all models, the precision was higher than accuracy which is likely the correct assumption for a serious medical condition.  For this reason, no effort was made to weight the dataset by over/under sampling.

# %%
plt.style.use('ggplot')

plt.figure(figsize=[12,12])
plt.subplot(211)
acc = my_history['acc']
val_acc = my_history['val_acc']
loss = my_history['loss']
val_loss = my_history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1.0))

plt.subplot(212)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1.0))

plt.show()

# %% [markdown]
# # <font color='green'>Conclusion</font>
#
# Model 3, CNN Dropout, was the most successful when measured for accuracy.
#
# It performed at 98.3% accuracy on the test set, with a 99.1% precision score.  That is the model deployed on the web app.  When rerun, the model achieved 97.7%, but all iterations were between 97-98.
#
# To increase the accuracy and improve the model, we could:
# - use bigger image size >150x150
# - use larger kernel on CNN
# - change the images in preprocessing (change brightness crop), maybe use open cv / pillow.
# - Further tune the model hyperparameters
# - add more images to the set
